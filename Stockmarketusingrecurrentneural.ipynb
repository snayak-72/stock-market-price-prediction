# %% [markdown]
# ### Stock Market Prediction And Forecasting Using Stacked LSTM

# %%
### Keras and Tensorflow >2.0

# %%
### Data Collection
import pandas_datareader as pdr
key=""

# %%
import pandas as pd
from google.colab import files

# %%
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6f273f6a-2df1-4439-a38e-10199b0212c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f273f6a-2df1-4439-a38e-10199b0212c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "AAPL.csv" with length 192243 bytes

# %%
df = pd.read_csv(io.StringIO(uploaded['AAPL.csv'].decode('utf-8')))

# %%
df.head()
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 symbol                       date   close    high       low  \
# 1253        1253   AAPL  2020-05-18 00:00:00+00:00  314.96  316.50  310.3241
# 1254        1254   AAPL  2020-05-19 00:00:00+00:00  313.14  318.52  313.0100
# 1255        1255   AAPL  2020-05-20 00:00:00+00:00  319.23  319.52  316.2000
# 1256        1256   AAPL  2020-05-21 00:00:00+00:00  316.85  320.89  315.8700
# 1257        1257   AAPL  2020-05-22 00:00:00+00:00  318.89  319.23  315.3500
#
#         open    volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  \
# 1253  313.17  33843125    314.96   316.50  310.3241   313.17   33843125
# 1254  315.03  25432385    313.14   318.52  313.0100   315.03   25432385
# 1255  316.68  27876215    319.23   319.52  316.2000   316.68   27876215
# 1256  318.66  25672211    316.85   320.89  315.8700   318.66   25672211
# 1257  315.77  20450754    318.89   319.23  315.3500   315.77   20450754
#
#       divCash  splitFactor
# 1253      0.0          1.0
# ...

# %%
df1=df.reset_index()['close']

# %%
df1
# Out:
# 0       132.045
# 1       131.780
# 2       130.280
# 3       130.535
# 4       129.960
#          ...
# 1253    314.960
# 1254    313.140
# 1255    319.230
# 1256    316.850
# 1257    318.890
# Name: close, Length: 1258, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df1)
plt.suptitle('Stock Market Graph from 2015 to 2020 for the stock(without RNN)', fontsize=8)
plt.xlabel("Number of days count starting from 02-05-2015 to 02-05-2020")
plt.ylabel("index value for each day with 1st day-02-05-2015  ,last day-02-05-2020")
# Out:
# Text(0, 0.5, 'index value for each day with 1st day-02-05-2015  ,last day-02-05-2020')

# %%
### LSTM are sensitive to the scale of the data. so we apply MinMax scaler

# %%
import numpy as np

# %%
df1
# Out:
# 0       132.045
# 1       131.780
# 2       130.280
# 3       130.535
# 4       129.960
#          ...
# 1253    314.960
# 1254    313.140
# 1255    319.230
# 1256    316.850
# 1257    318.890
# Name: close, Length: 1258, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
print(df1)
# Out:
# [[0.17607447]
#  [0.17495567]
#  [0.16862282]
#  ...
#  [0.96635143]
#  [0.9563033 ]
#  [0.96491598]]

# %%
##splitting dataset into train and test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (817, 441)

# %%
train_data
# Out:
# array([[0.17607447],
#        [0.17495567],
#        [0.16862282],
#        [0.1696994 ],
#        [0.16727181],
#        [0.16794731],
#        [0.16473866],
#        [0.16174111],
#        [0.1581525 ],
#        [0.15654817],
#        [0.16271215],
#        [0.1614878 ],
#        [0.1554927 ],
#        [0.15443722],
#        [0.15730811],
#        [0.15604154],
#        [0.15849025],
#        [0.15308621],
#        [0.15735033],
#        [0.15490163],
#        [0.15946129],
#        [0.15688592],
#        [0.1537195 ],
#        [0.14434687],
#        [0.14812547],
#        [0.15308621],
#        [0.15241071],
#        [0.15055307],
#        [0.14924428],
#        [0.13607194],
#        [0.12551718],
#        [0.13906949],
#        [0.14911762],
#        [0.14890653],
#        [0.15401503],
#        [0.16115005],
#        [0.16583636],
#        [0.17618002],
#        [0.17060711],
#        [0.14725998],
#        [0.14700667],
#        [0.14422021],
#        [0.13691632],
# ...

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (716, 100)
# (716,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (340, 100)
# (340,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 11s 315ms/step - loss: 0.0174 - val_loss: 0.0562
# Epoch 2/100
# 12/12 [==============================] - 2s 198ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 3/100
# 12/12 [==============================] - 2s 195ms/step - loss: 8.9767e-04 - val_loss: 0.0039
# Epoch 4/100
# 12/12 [==============================] - 3s 293ms/step - loss: 6.4330e-04 - val_loss: 0.0039
# Epoch 5/100
# 12/12 [==============================] - 2s 195ms/step - loss: 6.4140e-04 - val_loss: 0.0038
# Epoch 6/100
# 12/12 [==============================] - 2s 194ms/step - loss: 6.3204e-04 - val_loss: 0.0036
# Epoch 7/100
# 12/12 [==============================] - 2s 197ms/step - loss: 6.1070e-04 - val_loss: 0.0036
# Epoch 8/100
# 12/12 [==============================] - 2s 197ms/step - loss: 5.9635e-04 - val_loss: 0.0037
# Epoch 9/100
# 12/12 [==============================] - 3s 285ms/step - loss: 5.5776e-04 - val_loss: 0.0034
# Epoch 10/100
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# ...
# 11/11 [==============================] - 0s 36ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 142.07099551561012

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 236.09899167554994

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions

plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.suptitle('Stock Market Graph from 2015 to 2020 for the stock(BLUE-original,ORANGE-train predict,Green-test predict', fontsize=5
             )
plt.xlabel("Number of days count starting from 02-05-2015 to 02-05-2020")
plt.ylabel("index value for each day with 1st day-02-05-2015  ,last day-02-05-2020")
plt.show()

# %%
len(test_data)
# Out:
# 441

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.8583551465000423,
#  0.8866418981676942,
#  0.8743139407244789,
#  0.8843198513890065,
#  0.8783669678290975,
#  0.8986321033521913,
#  0.925821160179009,
#  0.9287764924427933,
#  0.9567677108840666,
#  0.9386979650426415,
#  0.933040614709111,
#  0.9495060373216249,
#  0.9642404796082076,
#  0.9551211686228154,
#  0.9598919192772104,
#  0.9663514312251966,
#  0.9624672802499368,
#  0.9229502659799038,
#  0.9598497002448705,
#  0.9879253567508233,
#  0.985941062230854,
#  0.9253145317909315,
#  0.9217259140420504,
#  0.964747107996285,
#  0.9757240564046274,
#  0.9915984125643842,
#  0.9697289538123788,
#  0.9761462467280253,
#  0.9679557544541082,
#  1.0000000000000002,
#  0.9901629654648318,
#  0.9905007177235499,
#  0.9653803934813816,
#  0.9848855864223593,
#  0.9708688676855528,
#  0.9402600692392133,
#  0.8774803681499621,
#  0.8348391454867856,
#  0.8541332432660644,
#  0.7733682344000676,
#  0.7726927298826314,
#  0.8801401671873683,
#  0.8400743054969182,
# ...

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.9337539]
# 101
# 1 day input [0.8866419  0.87431394 0.88431985 0.87836697 0.8986321  0.92582116
#  0.92877649 0.95676771 0.93869797 0.93304061 0.94950604 0.96424048
#  0.95512117 0.95989192 0.96635143 0.96246728 0.92295027 0.9598497
#  0.98792536 0.98594106 0.92531453 0.92172591 0.96474711 0.97572406
#  0.99159841 0.96972895 0.97614625 0.96795575 1.         0.99016297
#  0.99050072 0.96538039 0.98488559 0.97086887 0.94026007 0.87748037
#  0.83483915 0.85413324 0.77336823 0.77269273 0.88014017 0.84007431
#  0.89673225 0.85527316 0.83884995 0.74233725 0.82327113 0.78143207
#  0.6665963  0.7921557  0.64118044 0.68614371 0.66001013 0.65203074
#  0.58642236 0.56586169 0.66089673 0.65515494 0.70970193 0.66452757
#  0.69437642 0.69218104 0.63569197 0.65266402 0.63780292 0.7267162
#  0.71388162 0.74191506 0.75002111 0.77222832 0.83049059 0.8194292
#  0.8289707  0.8125475  0.78776492 0.75162543 0.78426074 0.77974331
#  0.81326522 0.8141096  0.79473106 0.83336148 0.85898843 0.83901883
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %%
len(df1)
# Out:
# 1258

# %%
plt.plot(day_new,scaler.inverse_transform(df1[1158:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))
plt.suptitle('Stock Market Graph from 1158th to 1258 for the stock(BLUE-original,ORANGE-future predict', fontsize=7
             )
plt.xlabel("Number of days count starting from 1158th day")
plt.ylabel("index value for each day for 1158th day till 1259th day")
# Out:
# Text(0, 0.5, 'index value for each day for 1158th day till 1259th day')

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[1200:])
plt.suptitle('Stock Market Graph from 1200th  for the stock', fontsize=7
             )
plt.xlabel("Number of days count starting from 1200th day")
plt.ylabel("index value for each day from 1158th(scaled) ")
# Out:
# Text(0, 0.5, 'index value for each day from 1158th(scaled) ')

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)
plt.suptitle('Stock Market Graph from 2015 to 2020 for the stockalong with future predict for 30 days', fontsize=6
             )
plt.xlabel("Number of days count starting from 02-05-2015 to 02-05-2020")
plt.ylabel("index value for each day with 1st day-02-05-2015  ,last day-02-05-2020")
# Out:
# Text(0, 0.5, 'index value for each day with 1st day-02-05-2015  ,last day-02-05-2020')
